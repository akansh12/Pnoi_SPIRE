# %%
import numpy as np
import time
import scipy.io as sio
import torch
import augment
import torchaudio
import python_speech_features as psf
import random
from os import path
import glob
from scipy.io import wavfile
import scipy
import soundfile as sf
import librosa
import os
# Out:
# /home/akansh/anaconda3/lib/python3.7/site-packages/torchaudio/backend/utils.py:54: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   '"sox" backend is being deprecated. '

# %%
import matplotlib.pyplot as plt

# %%
import librosa.display

# %%
from tqdm import tqdm

# %%
! python -m pip install git+https://github.com/facebookresearch/WavAugment.git
# Out:
# Collecting git+https://github.com/facebookresearch/WavAugment.git
#   Cloning https://github.com/facebookresearch/WavAugment.git to /tmp/pip-req-build-iekv9w6d
# Requirement already satisfied: torch in /home/akansh/anaconda3/lib/python3.7/site-packages (from augment==0.2) (1.7.0)
# Requirement already satisfied: torchaudio in /home/akansh/anaconda3/lib/python3.7/site-packages (from augment==0.2) (0.7.0)
# Requirement already satisfied: numpy in /home/akansh/anaconda3/lib/python3.7/site-packages (from torch->augment==0.2) (1.16.2)
# Requirement already satisfied: dataclasses in /home/akansh/anaconda3/lib/python3.7/site-packages (from torch->augment==0.2) (0.6)
# Requirement already satisfied: typing-extensions in /home/akansh/anaconda3/lib/python3.7/site-packages (from torch->augment==0.2) (3.7.4.3)
# Requirement already satisfied: future in /home/akansh/anaconda3/lib/python3.7/site-packages (from torch->augment==0.2) (0.17.1)
# Building wheels for collected packages: augment
#   Building wheel for augment (setup.py) ... done
#   Created wheel for augment: filename=augment-0.2-py3-none-any.whl size=5372 sha256=ca497affcfe62875d4242ed900c9445708b2f6eca3787e2822cf1656057f6305
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e4p5mrko/wheels/de/31/23/bb3c93de3e7e94bda500cba8eff0451435374f4e713d22b0a1
# Successfully built augment
# Installing collected packages: augment
# Successfully installed augment-0.2
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/akansh/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install python_speech_features
# Out:
# Collecting python_speech_features
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
# Building wheels for collected packages: python-speech-features
#   Building wheel for python-speech-features (setup.py) ... done
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-py3-none-any.whl size=5889 sha256=955b4ae664dc2969f4d72a4bb295d11f69b1642de54076c8af2b927bbdd3ef8b
#   Stored in directory: /home/akansh/.cache/pip/wheels/b0/0e/94/28cd6afa3cd5998a63eef99fe31777acd7d758f59cf24839eb
# Successfully built python-speech-features
# Installing collected packages: python-speech-features
# Successfully installed python-speech-features-0.6
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/akansh/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# augment_type=['reverb','uniform_noise']
# loc='/data1/shivani/';
# data_path=loc+'data_clipped/';
# dest_loc1=loc+'data_clipped_'+augment_type[0] +'/';
# dest_loc2=loc+'data_clipped_'+augment_type[1] +'/';

# if not os.path.isdir(dest_loc1):
#     os.mkdir(dest_loc1);
# if not os.path.isdir(dest_loc2):
#     os.mkdir(dest_loc2);

# files=glob.glob(data_path+'*.wav');
# for split_files in np.arange(0,len(files)):
#     sig, rate=librosa.load(data_loc+j+'/Eko/'+k,sr=None)
#     x = augment.EffectChain().reverb(50, 50, 50).channels(1).apply(torch.from_numpy(sig), src_info={'rate': rate})
#     x=x.numpy().squeeze();    
#     sf.write(dest_loc1+files[split_files][28:],x,rate)

#     noise_generator = lambda: torch.zeros_like(torch.from_numpy(sig)).uniform_()
#     snr=random.sample(range(5, 40), 1)
#     y = augment.EffectChain().additive_noise(noise_generator, snr=int(snr[0])).apply(torch.from_numpy(sig), src_info={'rate': rate})
#     y=y.numpy().squeeze(); 
#     sf.write(dest_loc2+files[split_files][28:],y,rate)

# %%
augment_type=['reverb','uniform_noise']
set_loc = "./Sets/"
data_loc = "./"
new_sr = 16000
for i in os.listdir(set_loc):
    set_full = np.loadtxt(set_loc + i, dtype=str)
    for j in tqdm(set_full):
        os.makedirs('./Augmented_Data/'+'Aug'+j)
        os.makedirs('./Augmented_Data/'+'Aug'+j+'/Eko')
        os.makedirs('./Augmented_Data/'+'Aug'+j+'/Mic')
        for k in os.listdir(data_loc+j+'/Eko'):
            sig, rate=librosa.load(data_loc+j+'/Eko/'+k,sr=None)
            x = augment.EffectChain().reverb(50, 50, 50).channels(1).apply(torch.from_numpy(sig), src_info={'rate': rate})
            x=x.numpy().squeeze(); 
            sf.write('./Augmented_Data/'+'Aug'+j+'/Eko/reverb'+k,x,rate)
            #ploting
#             plt.figure(figsize=(12, 8))
#             plt.subplot(3,1,1)
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(sig)), ref=np.max)
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}')
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(x)), ref=np.max)
#             plt.subplot(3, 1, 2)
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}')
            
            
            
#             noise_generator = lambda: torch.zeros_like(torch.from_numpy(sig)).uniform_()
#             snr=random.sample(range(5, 40), 1)
#             y = augment.EffectChain().additive_noise(noise_generator, snr=int(snr[0])).apply(torch.from_numpy(sig), src_info={'rate': rate})
#             y=y.numpy().squeeze(); 
#             sf.write('./Augmented_Data/'+'Aug'+j+'/Eko/uniform_noise'+k,y,rate)
            
#             z = x+y 
#             sf.write('./Augmented_Data/'+'Aug'+j+'/Eko/both'+k,z,rate)
            
            
            
            
        for k in os.listdir(data_loc+j+'/Mic'):
            sig, rate=librosa.load(data_loc+j+'/Mic/'+k,sr=None)
            sig = librosa.resample(sig, rate, new_sr)
            rate = new_sr
            x = augment.EffectChain().reverb(50, 50, 50).channels(1).apply(torch.from_numpy(sig), src_info={'rate': rate})
            x=x.numpy().squeeze();    
            sf.write('./Augmented_Data/'+'Aug'+j+'/Mic/reverb'+k,x,rate)

            noise_generator = lambda: torch.zeros_like(torch.from_numpy(sig)).uniform_()
            snr=random.sample(range(5, 40), 1)
            y = augment.EffectChain().additive_noise(noise_generator, snr=int(snr[0])).apply(torch.from_numpy(sig), src_info={'rate': rate})
            y=y.numpy().squeeze(); 
            sf.write('./Augmented_Data/'+'Aug'+j+'/Mic/uniform_noise'+'SNR:'+str(snr)+k,y,rate)

            z = x+y
            z = z/np.max(np.abs(z))
            sf.write('./Augmented_Data/'+'Aug'+j+'/Mic/both'+'SNR:'+str(snr)+k,z,rate)
            
            #ploting
#             plt.figure(figsize=(15, 10))
#             plt.subplot(5,1,1)
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(sig)), ref=np.max) #original
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}')
            
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(x)), ref=np.max) #reverb
#             plt.subplot(5, 1, 2)
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}{snr}')
            
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max) #noise
#             plt.subplot(5, 1, 3)
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}')
            
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(z)), ref=np.max) #both
#             plt.subplot(5, 1, 4)
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}')
# Out:
# 100%|██████████| 7/7 [03:32<00:00, 31.46s/it]
# 100%|██████████| 8/8 [04:15<00:00, 31.41s/it]
# 100%|██████████| 7/7 [03:05<00:00, 26.24s/it]
# 100%|██████████| 8/8 [03:38<00:00, 26.76s/it]
# 100%|██████████| 8/8 [03:24<00:00, 25.04s/it]
# 100%|██████████| 8/8 [03:40<00:00, 27.99s/it]
# 100%|██████████| 7/7 [03:07<00:00, 26.50s/it]

# %%
augment_type=['reverb','uniform_noise']
set_loc = "./Sets/"
data_loc = "./"
new_sr = 16000
for i in os.listdir(set_loc):
    set_full = np.loadtxt(set_loc + i, dtype=str)
    for j in tqdm(set_full):
#         os.makedirs('./Augmented_Data/'+'Aug'+j)
#         os.makedirs('./Augmented_Data/'+'Aug'+j+'/Eko')
#         os.makedirs('./Augmented_Data/'+'Aug'+j+'/Mic')
        for k in os.listdir(data_loc+j+'/Eko'):
            sig, rate=librosa.load(data_loc+j+'/Eko/'+k,sr=None)
            x = augment.EffectChain().reverb(50, 50, 50).channels(1).apply(torch.from_numpy(sig), src_info={'rate': rate})
            x=x.numpy().squeeze(); 
#             sf.write('./Augmented_Data/'+'Aug'+j+'/Eko/reverb'+k,x,rate)
#             ploting
            plt.figure(figsize=(12, 8))
            plt.subplot(3,1,1)
            D = librosa.amplitude_to_db(np.abs(librosa.stft(sig)), ref=np.max)
            librosa.display.specshow(D, y_axis='linear', sr=rate)
            plt.colorbar(format='%+2.0f dB')
            plt.title(f'Linear-frequency power spectrogram{k}')
            D = librosa.amplitude_to_db(np.abs(librosa.stft(x)), ref=np.max)
            plt.subplot(3, 1, 2)
            librosa.display.specshow(D, y_axis='linear', sr=rate)
            plt.colorbar(format='%+2.0f dB')
            plt.title(f'Linear-frequency power spectrogram{k}')
            
            
            
#             noise_generator = lambda: torch.zeros_like(torch.from_numpy(sig)).uniform_()
#             snr=random.sample(range(5, 40), 1)
#             y = augment.EffectChain().additive_noise(noise_generator, snr=int(snr[0])).apply(torch.from_numpy(sig), src_info={'rate': rate})
#             y=y.numpy().squeeze(); 
#             sf.write('./Augmented_Data/'+'Aug'+j+'/Eko/uniform_noise'+k,y,rate)
            
#             z = x+y 
#             sf.write('./Augmented_Data/'+'Aug'+j+'/Eko/both'+k,z,rate)
            
            
            
            
#         for k in os.listdir(data_loc+j+'/Mic'):
#             sig, rate=librosa.load(data_loc+j+'/Mic/'+k,sr=None)
#             sig = librosa.resample(sig, rate, new_sr)
#             rate = new_sr
#             x = augment.EffectChain().reverb(50, 50, 50).channels(1).apply(torch.from_numpy(sig), src_info={'rate': rate})
#             x=x.numpy().squeeze();    
# #             sf.write('./Augmented_Data/'+'Aug'+j+'/Mic/reverb'+k,x,rate)

#             noise_generator = lambda: torch.zeros_like(torch.from_numpy(sig)).uniform_()
#             snr=random.sample(range(5, 40), 1)
#             y = augment.EffectChain().additive_noise(noise_generator, snr=int(snr[0])).apply(torch.from_numpy(sig), src_info={'rate': rate})
#             y=y.numpy().squeeze(); 
# #             sf.write('./Augmented_Data/'+'Aug'+j+'/Mic/uniform_noise'+'SNR:'+str(snr)+k,y,rate)

#             z = x+y
#             z = z/np.max(np.abs(z))
# #             sf.write('./Augmented_Data/'+'Aug'+j+'/Mic/both'+'SNR:'+str(snr)+k,z,rate)
            
#             #ploting
#             plt.figure(figsize=(15, 10))
#             plt.subplot(5,1,1)
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(sig)), ref=np.max) #original
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}')
            
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(x)), ref=np.max) #reverb
#             plt.subplot(5, 1, 2)
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}{snr}')
            
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max) #noise
#             plt.subplot(5, 1, 3)
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}')
            
#             D = librosa.amplitude_to_db(np.abs(librosa.stft(z)), ref=np.max) #both
#             plt.subplot(5, 1, 4)
#             librosa.display.specshow(D, y_axis='linear', sr=rate)
#             plt.colorbar(format='%+2.0f dB')
#             plt.title(f'Linear-frequency power spectrogram{k}')
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:01<00:10,  1.74s/it]
#  29%|██▊       | 2/7 [00:03<00:08,  1.71s/it]/home/akansh/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
#
#  43%|████▎     | 3/7 [00:05<00:07,  1.78s/it]
#  57%|█████▋    | 4/7 [00:07<00:05,  1.83s/it]
#  71%|███████▏  | 5/7 [00:09<00:03,  1.82s/it]
#  86%|████████▌ | 6/7 [00:11<00:01,  1.92s/it]
# 100%|██████████| 7/7 [00:13<00:00,  2.00s/it]
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(12, 8))
plt.subplot(3,1,1)
D = librosa.amplitude_to_db(np.abs(librosa.stft(sig)))
librosa.display.specshow(D, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title(f'Linear-frequency power spectrogram{k}')
D = librosa.amplitude_to_db(np.abs(librosa.stft(x)))
plt.subplot(3, 1, 2)
librosa.display.specshow(D, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title(f'Linear-frequency power spectrogram {k}')
# Out:
# Text(0.5, 1.0, 'Linear-frequency power spectrogram Meghanapriya_Eko_2019_12_18_13_48_26.040_B_R_T_DPB_1.wav')

# %% [markdown]
# ### Random Chunks
